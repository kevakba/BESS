# %% [markdown]
# #### Library

# %%
import pandas as pd
# Set pandas options to display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning)

from xgboost import XGBRegressor
import sklearn
from sklearn.metrics import mean_squared_error, r2_score
from catboost import CatBoostRegressor

# %% [markdown]
# #### Data Loading

# %%
df = pd.read_csv('/home/kevin/Downloads/BESS/data/raw/merged_df_2024.csv')

# %% [markdown]
# #### Data Cleaning

# %%
df.shape
# Out:
# (8787, 67)

# %%
df.head()
# Out:
#              datetime_  pool_price  forecast_pool_price  \
# 0  2024-01-01 00:00:00       23.05                20.57
# 1  2024-01-01 01:00:00       22.67                19.69
# 2  2024-01-01 02:00:00       24.07                21.46
# 3  2024-01-01 03:00:00       24.33                24.21
# 4  2024-01-01 04:00:00       24.70                24.48
#
#    rolling_30day_avg_price  alberta_internal_load  \
# 0                    51.98                 9809.0
# 1                    51.97                 9702.0
# 2                    51.96                 9560.0
# 3                    51.93                 9547.0
# 4                    51.93                 9511.0
#
#    forecast_alberta_internal_load  solar_generation  wind_generation  \
# 0                          9779.0               0.0      2905.627906
# 1                          9709.0               0.0      2857.032152
# 2                          9615.0               0.0      2519.803339
# 3                          9510.0               0.0      2386.924303
# 4                          9545.0               0.0      2222.338043
#
#    temp_calgary  temp_edmonton  temp_fortmc  ws_calgary  ws_edmonton  \
# 0           3.0           -0.5          2.5         8.0         10.0
# 1           3.0           -2.5          2.0         5.0          7.0
# 2           3.2           -4.3          0.7         5.0          9.0
# 3           2.9           -3.5         -0.5        16.0         12.0
# 4           2.4           -4.7          0.1        19.0          5.0
#
#    ws_fortmc  hour_of_day  day_of_week  week_of_month  month  season  \
# 0       16.0            0            0              1      1  winter
# 1       16.0            1            0              1      1  winter
# 2       16.0            2            0              1      1  winter
# 3       14.0            3            0              1      1  winter
# 4       16.0            4            0              1      1  winter
#
#    pool_price_lag_1  pool_price_lag_2  pool_price_lag_3  pool_price_lag_4  \
# 0               NaN               NaN               NaN               NaN
# 1             23.05               NaN               NaN               NaN
# 2             22.67             23.05               NaN               NaN
# 3             24.07             22.67             23.05               NaN
# 4             24.33             24.07             22.67             23.05
#
#    pool_price_lag_5  pool_price_lag_6  pool_price_lag_7  pool_price_lag_8  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#    pool_price_lag_9  pool_price_lag_10  pool_price_lag_11  pool_price_lag_12  \
# 0               NaN                NaN                NaN                NaN
# 1               NaN                NaN                NaN                NaN
# 2               NaN                NaN                NaN                NaN
# 3               NaN                NaN                NaN                NaN
# 4               NaN                NaN                NaN                NaN
#
#    pool_price_lag_13  pool_price_lag_14  pool_price_lag_15  pool_price_lag_16  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    pool_price_lag_17  pool_price_lag_18  pool_price_lag_19  pool_price_lag_20  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    pool_price_lag_21  pool_price_lag_22  pool_price_lag_23  pool_price_lag_24  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    alberta_internal_load_lag_1  alberta_internal_load_lag_2  \
# 0                          NaN                          NaN
# 1                       9809.0                          NaN
# 2                       9702.0                       9809.0
# 3                       9560.0                       9702.0
# 4                       9547.0                       9560.0
#
#    alberta_internal_load_lag_3  alberta_internal_load_lag_4  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                       9809.0                          NaN
# 4                       9702.0                       9809.0
#
#    alberta_internal_load_lag_5  alberta_internal_load_lag_6  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    alberta_internal_load_lag_7  alberta_internal_load_lag_8  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    alberta_internal_load_lag_9  alberta_internal_load_lag_10  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    alberta_internal_load_lag_11  alberta_internal_load_lag_12  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    alberta_internal_load_lag_13  alberta_internal_load_lag_14  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    alberta_internal_load_lag_15  alberta_internal_load_lag_16  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    alberta_internal_load_lag_17  alberta_internal_load_lag_18  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    alberta_internal_load_lag_19  alberta_internal_load_lag_20  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    alberta_internal_load_lag_21  alberta_internal_load_lag_22  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    alberta_internal_load_lag_23  alberta_internal_load_lag_24
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# alberta_internal_load_lag_24      25
# pool_price_lag_24                 25
# alberta_internal_load_lag_23      24
# pool_price_lag_23                 24
# alberta_internal_load_lag_22      23
# pool_price_lag_22                 23
# pool_price_lag_21                 22
# alberta_internal_load_lag_21      22
# alberta_internal_load_lag_20      21
# pool_price_lag_20                 21
# alberta_internal_load_lag_19      20
# pool_price_lag_19                 20
# alberta_internal_load_lag_18      19
# pool_price_lag_18                 19
# pool_price_lag_17                 18
# alberta_internal_load_lag_17      18
# pool_price_lag_16                 17
# alberta_internal_load_lag_16      17
# alberta_internal_load_lag_15      16
# pool_price_lag_15                 16
# alberta_internal_load_lag_14      15
# temp_edmonton                     15
# ws_edmonton                       15
# pool_price_lag_14                 15
# alberta_internal_load_lag_13      14
# pool_price_lag_13                 14
# alberta_internal_load_lag_12      13
# pool_price_lag_12                 13
# alberta_internal_load_lag_11      12
# pool_price_lag_11                 12
# ws_calgary                        11
# alberta_internal_load_lag_10      11
# pool_price_lag_10                 11
# alberta_internal_load_lag_9       10
# pool_price_lag_9                  10
# temp_calgary                       9
# pool_price_lag_8                   9
# alberta_internal_load_lag_8        9
# pool_price_lag_7                   8
# ws_fortmc                          8
# temp_fortmc                        8
# alberta_internal_load_lag_7        8
# alberta_internal_load_lag_6        7
# pool_price_lag_6                   7
# pool_price_lag_5                   6
# alberta_internal_load_lag_5        6
# pool_price_lag_4                   5
# alberta_internal_load_lag_4        5
# pool_price_lag_3                   4
# alberta_internal_load_lag_3        4
# alberta_internal_load_lag_2        3
# pool_price_lag_2                   3
# alberta_internal_load_lag_1        2
# pool_price_lag_1                   2
# pool_price                         1
# wind_generation                    1
# solar_generation                   1
# forecast_alberta_internal_load     1
# alberta_internal_load              1
# rolling_30day_avg_price            1
# forecast_pool_price                1
# hour_of_day                        0
# day_of_week                        0
# week_of_month                      0
# month                              0
# season                             0
# datetime_                          0
# dtype: int64

# %%
# Filter columns that do not start with 'alberta' or 'pool'
filtered_columns = [col for col in df.columns if not col.startswith('alberta') and not col.startswith('pool')]

# Display the sum of null values for the filtered columns
df[filtered_columns].isnull().sum()#.sort_values(ascending=False)
# Out:
# datetime_                          0
# forecast_pool_price                1
# rolling_30day_avg_price            1
# forecast_alberta_internal_load     1
# solar_generation                   1
# wind_generation                    1
# temp_calgary                       9
# temp_edmonton                     15
# temp_fortmc                        8
# ws_calgary                        11
# ws_edmonton                       15
# ws_fortmc                          8
# hour_of_day                        0
# day_of_week                        0
# week_of_month                      0
# month                              0
# season                             0
# dtype: int64

# %%
# impute median for missing values

df['pool_price'].fillna(df.pool_price.median(), inplace=True)
df['alberta_internal_load'].fillna(df.alberta_internal_load.median(), inplace=True)

df['forecast_pool_price'].fillna(df.forecast_pool_price.median(), inplace=True)
df['rolling_30day_avg_price'].fillna(df.rolling_30day_avg_price.median(), inplace=True)
df['forecast_alberta_internal_load'].fillna(df.forecast_alberta_internal_load.median(), inplace=True)

df['solar_generation'].fillna(df.solar_generation.median(), inplace=True)
df['wind_generation'].fillna(df.wind_generation.median(), inplace=True)

df['temp_calgary'].fillna(df.temp_calgary.median(), inplace=True)
df['temp_edmonton'].fillna(df.temp_edmonton.median(), inplace=True)
df['temp_fortmc'].fillna(df.temp_fortmc.median(), inplace=True)

df['ws_calgary'].fillna(df.ws_calgary.median(), inplace=True)
df['ws_edmonton'].fillna(df.ws_edmonton.median(), inplace=True)
df['ws_fortmc'].fillna(df.ws_fortmc.median(), inplace=True)
# Out:
# /tmp/ipykernel_12197/4150987496.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['pool_price'].fillna(df.pool_price.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['alberta_internal_load'].fillna(df.alberta_internal_load.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['forecast_pool_price'].fillna(df.forecast_pool_price.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rolling_30day_avg_price'].fillna(df.rolling_30day_avg_price.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['forecast_alberta_internal_load'].fillna(df.forecast_alberta_internal_load.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['solar_generation'].fillna(df.solar_generation.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['wind_generation'].fillna(df.wind_generation.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['temp_calgary'].fillna(df.temp_calgary.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['temp_edmonton'].fillna(df.temp_edmonton.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['temp_fortmc'].fillna(df.temp_fortmc.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ws_calgary'].fillna(df.ws_calgary.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ws_edmonton'].fillna(df.ws_edmonton.median(), inplace=True)
# /tmp/ipykernel_12197/4150987496.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ws_fortmc'].fillna(df.ws_fortmc.median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# datetime_                          0
# pool_price                         0
# forecast_pool_price                0
# rolling_30day_avg_price            0
# alberta_internal_load              0
# forecast_alberta_internal_load     0
# solar_generation                   0
# wind_generation                    0
# temp_calgary                       0
# temp_edmonton                      0
# temp_fortmc                        0
# ws_calgary                         0
# ws_edmonton                        0
# ws_fortmc                          0
# hour_of_day                        0
# day_of_week                        0
# week_of_month                      0
# month                              0
# season                             0
# pool_price_lag_1                   2
# pool_price_lag_2                   3
# pool_price_lag_3                   4
# pool_price_lag_4                   5
# pool_price_lag_5                   6
# pool_price_lag_6                   7
# pool_price_lag_7                   8
# pool_price_lag_8                   9
# pool_price_lag_9                  10
# pool_price_lag_10                 11
# pool_price_lag_11                 12
# pool_price_lag_12                 13
# pool_price_lag_13                 14
# pool_price_lag_14                 15
# pool_price_lag_15                 16
# pool_price_lag_16                 17
# pool_price_lag_17                 18
# pool_price_lag_18                 19
# pool_price_lag_19                 20
# pool_price_lag_20                 21
# pool_price_lag_21                 22
# pool_price_lag_22                 23
# pool_price_lag_23                 24
# pool_price_lag_24                 25
# alberta_internal_load_lag_1        2
# alberta_internal_load_lag_2        3
# alberta_internal_load_lag_3        4
# alberta_internal_load_lag_4        5
# alberta_internal_load_lag_5        6
# alberta_internal_load_lag_6        7
# alberta_internal_load_lag_7        8
# alberta_internal_load_lag_8        9
# alberta_internal_load_lag_9       10
# alberta_internal_load_lag_10      11
# alberta_internal_load_lag_11      12
# alberta_internal_load_lag_12      13
# alberta_internal_load_lag_13      14
# alberta_internal_load_lag_14      15
# alberta_internal_load_lag_15      16
# alberta_internal_load_lag_16      17
# alberta_internal_load_lag_17      18
# alberta_internal_load_lag_18      19
# alberta_internal_load_lag_19      20
# alberta_internal_load_lag_20      21
# alberta_internal_load_lag_21      22
# alberta_internal_load_lag_22      23
# alberta_internal_load_lag_23      24
# alberta_internal_load_lag_24      25
# dtype: int64

# %%
# fill NAN with bfill method
lagged_columns = [f'pool_price_lag_{i}' for i in range(1, 25)] + [f'alberta_internal_load_lag_{i}' for i in range(1, 25)]

df[lagged_columns] = df[lagged_columns].fillna(method='bfill')
# Verify if NaN values are filled
print(df[lagged_columns].isnull().sum().sort_values(ascending=False))
# Out:
# pool_price_lag_1                0
# pool_price_lag_2                0
# alberta_internal_load_lag_3     0
# alberta_internal_load_lag_4     0
# alberta_internal_load_lag_5     0
# alberta_internal_load_lag_6     0
# alberta_internal_load_lag_7     0
# alberta_internal_load_lag_8     0
# alberta_internal_load_lag_9     0
# alberta_internal_load_lag_10    0
# alberta_internal_load_lag_11    0
# alberta_internal_load_lag_12    0
# alberta_internal_load_lag_13    0
# alberta_internal_load_lag_14    0
# alberta_internal_load_lag_15    0
# alberta_internal_load_lag_16    0
# alberta_internal_load_lag_17    0
# alberta_internal_load_lag_18    0
# alberta_internal_load_lag_19    0
# alberta_internal_load_lag_20    0
# alberta_internal_load_lag_21    0
# alberta_internal_load_lag_22    0
# alberta_internal_load_lag_23    0
# alberta_internal_load_lag_2     0
# alberta_internal_load_lag_1     0
# pool_price_lag_24               0
# pool_price_lag_12               0
# pool_price_lag_3                0
# pool_price_lag_4                0
# pool_price_lag_5                0
# pool_price_lag_6                0
# pool_price_lag_7                0
# pool_price_lag_8                0
# pool_price_lag_9                0
# pool_price_lag_10               0
# pool_price_lag_11               0
# pool_price_lag_13               0
# pool_price_lag_23               0
# pool_price_lag_14               0
# pool_price_lag_15               0
# pool_price_lag_16               0
# pool_price_lag_17               0
# pool_price_lag_18               0
# pool_price_lag_19               0
# pool_price_lag_20               0
# pool_price_lag_21               0
# pool_price_lag_22               0
# alberta_internal_load_lag_24    0
# dtype: int64
# /tmp/ipykernel_12197/1257025338.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[lagged_columns] = df[lagged_columns].fillna(method='bfill')

# %%
# we have 12 months of data

# use 11 months of data to train ML model
    # independent variable: solar_generation, wind_generation, temp_calgary, temp_edmonton, temp_fortmc
    # target variable: pool_price

# use 1 month of data to test ML model

# %%
df.head()
# Out:
#              datetime_  pool_price  forecast_pool_price  \
# 0  2024-01-01 00:00:00       23.05                20.57
# 1  2024-01-01 01:00:00       22.67                19.69
# 2  2024-01-01 02:00:00       24.07                21.46
# 3  2024-01-01 03:00:00       24.33                24.21
# 4  2024-01-01 04:00:00       24.70                24.48
#
#    rolling_30day_avg_price  alberta_internal_load  \
# 0                    51.98                 9809.0
# 1                    51.97                 9702.0
# 2                    51.96                 9560.0
# 3                    51.93                 9547.0
# 4                    51.93                 9511.0
#
#    forecast_alberta_internal_load  solar_generation  wind_generation  \
# 0                          9779.0               0.0      2905.627906
# 1                          9709.0               0.0      2857.032152
# 2                          9615.0               0.0      2519.803339
# 3                          9510.0               0.0      2386.924303
# 4                          9545.0               0.0      2222.338043
#
#    temp_calgary  temp_edmonton  temp_fortmc  ws_calgary  ws_edmonton  \
# 0           3.0           -0.5          2.5         8.0         10.0
# 1           3.0           -2.5          2.0         5.0          7.0
# 2           3.2           -4.3          0.7         5.0          9.0
# 3           2.9           -3.5         -0.5        16.0         12.0
# 4           2.4           -4.7          0.1        19.0          5.0
#
#    ws_fortmc  hour_of_day  day_of_week  week_of_month  month  season  \
# 0       16.0            0            0              1      1  winter
# 1       16.0            1            0              1      1  winter
# 2       16.0            2            0              1      1  winter
# 3       14.0            3            0              1      1  winter
# 4       16.0            4            0              1      1  winter
#
#    pool_price_lag_1  pool_price_lag_2  pool_price_lag_3  pool_price_lag_4  \
# 0             23.05             23.05             23.05             23.05
# 1             23.05             23.05             23.05             23.05
# 2             22.67             23.05             23.05             23.05
# 3             24.07             22.67             23.05             23.05
# 4             24.33             24.07             22.67             23.05
#
#    pool_price_lag_5  pool_price_lag_6  pool_price_lag_7  pool_price_lag_8  \
# 0             23.05             23.05             23.05             23.05
# 1             23.05             23.05             23.05             23.05
# 2             23.05             23.05             23.05             23.05
# 3             23.05             23.05             23.05             23.05
# 4             23.05             23.05             23.05             23.05
#
#    pool_price_lag_9  pool_price_lag_10  pool_price_lag_11  pool_price_lag_12  \
# 0             23.05              23.05              23.05              23.05
# 1             23.05              23.05              23.05              23.05
# 2             23.05              23.05              23.05              23.05
# 3             23.05              23.05              23.05              23.05
# 4             23.05              23.05              23.05              23.05
#
#    pool_price_lag_13  pool_price_lag_14  pool_price_lag_15  pool_price_lag_16  \
# 0              23.05              23.05              23.05              23.05
# 1              23.05              23.05              23.05              23.05
# 2              23.05              23.05              23.05              23.05
# 3              23.05              23.05              23.05              23.05
# 4              23.05              23.05              23.05              23.05
#
#    pool_price_lag_17  pool_price_lag_18  pool_price_lag_19  pool_price_lag_20  \
# 0              23.05              23.05              23.05              23.05
# 1              23.05              23.05              23.05              23.05
# 2              23.05              23.05              23.05              23.05
# 3              23.05              23.05              23.05              23.05
# 4              23.05              23.05              23.05              23.05
#
#    pool_price_lag_21  pool_price_lag_22  pool_price_lag_23  pool_price_lag_24  \
# 0              23.05              23.05              23.05              23.05
# 1              23.05              23.05              23.05              23.05
# 2              23.05              23.05              23.05              23.05
# 3              23.05              23.05              23.05              23.05
# 4              23.05              23.05              23.05              23.05
#
#    alberta_internal_load_lag_1  alberta_internal_load_lag_2  \
# 0                       9809.0                       9809.0
# 1                       9809.0                       9809.0
# 2                       9702.0                       9809.0
# 3                       9560.0                       9702.0
# 4                       9547.0                       9560.0
#
#    alberta_internal_load_lag_3  alberta_internal_load_lag_4  \
# 0                       9809.0                       9809.0
# 1                       9809.0                       9809.0
# 2                       9809.0                       9809.0
# 3                       9809.0                       9809.0
# 4                       9702.0                       9809.0
#
#    alberta_internal_load_lag_5  alberta_internal_load_lag_6  \
# 0                       9809.0                       9809.0
# 1                       9809.0                       9809.0
# 2                       9809.0                       9809.0
# 3                       9809.0                       9809.0
# 4                       9809.0                       9809.0
#
#    alberta_internal_load_lag_7  alberta_internal_load_lag_8  \
# 0                       9809.0                       9809.0
# 1                       9809.0                       9809.0
# 2                       9809.0                       9809.0
# 3                       9809.0                       9809.0
# 4                       9809.0                       9809.0
#
#    alberta_internal_load_lag_9  alberta_internal_load_lag_10  \
# 0                       9809.0                        9809.0
# 1                       9809.0                        9809.0
# 2                       9809.0                        9809.0
# 3                       9809.0                        9809.0
# 4                       9809.0                        9809.0
#
#    alberta_internal_load_lag_11  alberta_internal_load_lag_12  \
# 0                        9809.0                        9809.0
# 1                        9809.0                        9809.0
# 2                        9809.0                        9809.0
# 3                        9809.0                        9809.0
# 4                        9809.0                        9809.0
#
#    alberta_internal_load_lag_13  alberta_internal_load_lag_14  \
# 0                        9809.0                        9809.0
# 1                        9809.0                        9809.0
# 2                        9809.0                        9809.0
# 3                        9809.0                        9809.0
# 4                        9809.0                        9809.0
#
#    alberta_internal_load_lag_15  alberta_internal_load_lag_16  \
# 0                        9809.0                        9809.0
# 1                        9809.0                        9809.0
# 2                        9809.0                        9809.0
# 3                        9809.0                        9809.0
# 4                        9809.0                        9809.0
#
#    alberta_internal_load_lag_17  alberta_internal_load_lag_18  \
# 0                        9809.0                        9809.0
# 1                        9809.0                        9809.0
# 2                        9809.0                        9809.0
# 3                        9809.0                        9809.0
# 4                        9809.0                        9809.0
#
#    alberta_internal_load_lag_19  alberta_internal_load_lag_20  \
# 0                        9809.0                        9809.0
# 1                        9809.0                        9809.0
# 2                        9809.0                        9809.0
# 3                        9809.0                        9809.0
# 4                        9809.0                        9809.0
#
#    alberta_internal_load_lag_21  alberta_internal_load_lag_22  \
# 0                        9809.0                        9809.0
# 1                        9809.0                        9809.0
# 2                        9809.0                        9809.0
# 3                        9809.0                        9809.0
# 4                        9809.0                        9809.0
#
#    alberta_internal_load_lag_23  alberta_internal_load_lag_24
# 0                        9809.0                        9809.0
# 1                        9809.0                        9809.0
# 2                        9809.0                        9809.0
# 3                        9809.0                        9809.0
# 4                        9809.0                        9809.0

# %%
df.shape
# Out:
# (8787, 67)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# datetime_                         0
# alberta_internal_load_lag_8       0
# pool_price_lag_18                 0
# pool_price_lag_19                 0
# pool_price_lag_20                 0
# pool_price_lag_21                 0
# pool_price_lag_22                 0
# pool_price_lag_23                 0
# pool_price_lag_24                 0
# alberta_internal_load_lag_1       0
# alberta_internal_load_lag_2       0
# alberta_internal_load_lag_3       0
# alberta_internal_load_lag_4       0
# alberta_internal_load_lag_5       0
# alberta_internal_load_lag_6       0
# alberta_internal_load_lag_7       0
# alberta_internal_load_lag_9       0
# pool_price_lag_16                 0
# alberta_internal_load_lag_10      0
# alberta_internal_load_lag_11      0
# alberta_internal_load_lag_12      0
# alberta_internal_load_lag_13      0
# alberta_internal_load_lag_14      0
# alberta_internal_load_lag_15      0
# alberta_internal_load_lag_16      0
# alberta_internal_load_lag_17      0
# alberta_internal_load_lag_18      0
# alberta_internal_load_lag_19      0
# alberta_internal_load_lag_20      0
# alberta_internal_load_lag_21      0
# alberta_internal_load_lag_22      0
# alberta_internal_load_lag_23      0
# pool_price_lag_17                 0
# pool_price_lag_15                 0
# pool_price                        0
# week_of_month                     0
# forecast_pool_price               0
# rolling_30day_avg_price           0
# alberta_internal_load             0
# forecast_alberta_internal_load    0
# solar_generation                  0
# wind_generation                   0
# temp_calgary                      0
# temp_edmonton                     0
# temp_fortmc                       0
# ws_calgary                        0
# ws_edmonton                       0
# ws_fortmc                         0
# hour_of_day                       0
# day_of_week                       0
# month                             0
# pool_price_lag_14                 0
# season                            0
# pool_price_lag_1                  0
# pool_price_lag_2                  0
# pool_price_lag_3                  0
# pool_price_lag_4                  0
# pool_price_lag_5                  0
# pool_price_lag_6                  0
# pool_price_lag_7                  0
# pool_price_lag_8                  0
# pool_price_lag_9                  0
# pool_price_lag_10                 0
# pool_price_lag_11                 0
# pool_price_lag_12                 0
# pool_price_lag_13                 0
# alberta_internal_load_lag_24      0
# dtype: int64

# %% [markdown]
# #### Save csv

# %%
df.to_csv('/home/kevin/Downloads/BESS/data/raw/merged_df_2024_cleaned.csv', index=False)
